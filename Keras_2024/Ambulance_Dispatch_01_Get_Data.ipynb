# %%
# %%latex
# \tableofcontents
# Out:
# \tableofcontents

# %% [markdown]
# # Get Data
#
# This file
#
#     - Pulls the data from the '../../Big_Files' folder (not in the GitHub repository) for each year,
#     - From each year pulls the Accident, Vehicle, and Person .csv files,
#     - Drops features in the Vehicle and Person files that are repeats of features in the other files,
#     - Drops features that are not useful, even for imputing missing data, and
#     - Writes the results to one big file, '../../Big_Files/CRSS_Merged_Raw_Data.csv'.
#
# In a change from our previous versions, we will keep the crashes involving pedestrians through the imputation stages, then drop them when building the models.

# %% [markdown]
# # readme
# ## Directory Structure

# %% [markdown]
# We designed this code to fit in a GitHub repository with files under 100MB.  Many of the files we input are over this limit, and after preprocessing (selecting features, binning features) we saved the data as a .csv file of about 150 MB so we can tweak later code without having to run the preprocessing again.  We saved it again after imputing missing data.  To keep the files in our GitHub repository under 100 MB, we saved these into a different directory.

# %% [markdown]
# - CRSS Data Files
#     - We use seven years of data, 2016-2022. Once later years come out, they can be easily added.
#     - Each year's data is 100-200 MB
#     - The files we're really interested in each year are these.  The names were uppercase until 2018, then lowercase, and also after 2018 the file sizes jumped.
#         - accident.csv or ACCIDENT.csv, now about 30 MB
#         - vehicle.csv or VEHICLE.csv, now about 180 MB
#         - person.csv or PERSON.csv, now about 150 MB

# %% [markdown]
# - Big_Files
#     - CRSS_Files
#         - CRSS2016CSV (22 files, 160 MB)
#         - CRSS2017CSV (22 files, 189 MB)
#         - CRSS2018CSV (22 files, 169 MB)
#         - CRSS2019CSV (23 files, 633 MB)
#         - CRSS2020CSV (29 files, 719 MB)
#         - CRSS2021CSV (29 files, 736 MB)
#         - CRSS2022CSV (29 files, 738 MB)
#
#
#     - *Intermediate .csv files*
# - GitHub_Repository
#     - Code_Files
#         - Analyze_Proba
#         - Confusion_Matrices
#         - Images

# %% [markdown]
# # Setup

# %% [markdown]
# ## Import Libraries

# %%
print ('Install Packages')

import sys, copy, math, time, os

print ('Python version: {}'.format(sys.version))

import numpy as np
print ('NumPy version: {}'.format(np.__version__))
np.set_printoptions(suppress=True)

import pandas as pd
print ('Pandas version:  {}'.format(pd.__version__))
pd.set_option('display.max_rows', 500)

import json # We will use json ('JavaScript Object Notation') to write and read dictionaries to/from files
print ('JSON version:  {}'.format(json.__version__))

# Set Randomness.  Copied from https://www.kaggle.com/code/abazdyrev/keras-nn-focal-loss-experiments
import random
#np.random.seed(42) # NumPy
#random.seed(42) # Python
#tf.random.set_seed(42) # Tensorflow

import warnings
warnings.filterwarnings('ignore')

print ('Finished Installing Packages')
print ()
# Out:
# Install Packages
# Python version: 3.10.9 | packaged by conda-forge | (main, Feb  2 2023, 20:26:08) [Clang 14.0.6 ]
# NumPy version: 1.24.2
# Pandas version:  1.5.3
# JSON version:  2.0.9
# Finished Installing Packages

# %% [markdown]
# # Get Data and Preprocess

# %% [markdown]
# ## Read CRSS Files
# - We have the CRSS dataset in
#     - Big_Files/CRSS_2020_Update/
# - In one directory for each year,
#     - CRSS2016CSV
#     - CRSS2017CSV
#     - CRSS2018CSV
#     - CRSS2019CSV
#     - CRSS2020CSV
#     - CRSS2021CSV
# - In each year, the CRSS dataset comes in three main files,
#     - Accident.csv
#     - Vehicle.csv
#     - Person.csv
# - Collect those and merge into three files,
#     - Accident_Raw.csv
#     - Vehicle_Raw.csv
#     - Person_Raw.csv
# - and also three files with category names,
#     - Accident_Raw_with_Names.csv
#     - Vehicle_Raw_with_Names.csv
#     - Person_Raw_with_Names.csv

# %% [markdown]
# ### accident.csv from CRSS

# %%
def Import_Data_Accident(NAMES):
    print ('Import_Data_Accident()')

    df = pd.DataFrame([])
#    for year in ['2018']:
    for year in ['2016','2017','2018']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/ACCIDENT.CSV'
        temp = pd.read_csv(filename, index_col=None)
        print (year, len(temp))
        df = df.append(temp)

#    for year in ['2020']:
    for year in ['2019','2020','2021', '2022']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/accident.csv'
        temp = pd.read_csv(filename, index_col=None)
        print (year, len(temp))
        df = df.append(temp)
    
    if NAMES==0:
        for feature in df:
            if 'NAME' in feature:
                df.drop(columns=[feature], inplace=True)

    print (df.shape)
    print ()
    return df

# %% [markdown]
# ### vehicle.csv from CRSS

# %%
def Import_Data_Vehicle(NAMES):
    print ('Import_Data_Vehicle()')

    df = pd.DataFrame([])
    for year in ['2016','2017','2018']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/VEHICLE.CSV'
        temp = pd.read_csv(filename, index_col=None, low_memory=False)
        print (year, len(temp))
        df = df.append(temp)

    for year in ['2019','2020','2021', '2022']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/vehicle.csv'
        temp = pd.read_csv(filename, index_col=None, encoding='latin1', low_memory=False)
        print (year, len(temp))
        df = df.append(temp)

    if NAMES==0:
        for feature in df:
            if 'NAME' in feature:
                df.drop(columns=[feature], inplace=True)

    print (df.shape)
    print ()
    return df

# %% [markdown]
# ### person.csv from CRSS

# %%
def Import_Data_Person(NAMES):
    print ('Import_Data_Person()')

    df = pd.DataFrame([])
    for year in ['2016','2017','2018']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/PERSON.CSV'
        temp = pd.read_csv(filename, index_col=None)
        print (year, len(temp))
        df = df.append(temp)

    for year in ['2019','2020','2021', '2022']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/person.csv'
        temp = pd.read_csv(filename, index_col=None, encoding='latin1')
        print (year, len(temp))
        df = df.append(temp)

    if NAMES==0:
        for feature in df:
            if 'NAME' in feature:
                df.drop(columns=[feature], inplace=True)

    print (df.shape)
    print ()
    return df

# %% [markdown]
# ### Get Data
# - The Get_Data_from_Original() reads the (original) CRSS files from the CRSS directory, preprocesses it, and writes it to files in a folder outside this GitHub repo (because the files are too large for my subscription), and returns the dataframes.
# - The Get_Data_from_Temp_Files() reads the temp files and returns the dataframes.  I created this option for running repeatedly during writing and debugging, because it's much faster.

# %%
def Get_Data_from_Original():
    print ('Get_Data_from_Original()')
    
    df_Accident = Import_Data_Accident(0)
    df_Vehicle = Import_Data_Vehicle(0)
    df_Person = Import_Data_Person(0)
    
    df_Accident.to_csv('../../Big_Files/Accident_Raw.csv', index=False)
    df_Vehicle.to_csv('../../Big_Files/Vehicle_Raw.csv', index=False)
    df_Person.to_csv('../../Big_Files/Person_Raw.csv', index=False)
    

    df_Accident = Import_Data_Accident(1)
    df_Vehicle = Import_Data_Vehicle(1)
    df_Person = Import_Data_Person(1)
    
    df_Accident.to_csv('../../Big_Files/Accident_Raw_with_NAMES.csv', index=False)
    df_Vehicle.to_csv('../../Big_Files/Vehicle_Raw_with_NAMES.csv', index=False)
    df_Person.to_csv('../../Big_Files/Person_Raw_with_NAMES.csv', index=False)
    

    return df_Accident, df_Vehicle, df_Person

#df_Accident, df_Vehicle, df_Person = Get_Data_from_Original()

# %%
def Get_Data_from_Temp_Files():
    print ('Get_Data')
    df_Acc = pd.read_csv('../../Big_Files/Accident_Raw.csv', low_memory=False)
    df_Veh = pd.read_csv('../../Big_Files/Vehicle_Raw.csv', low_memory=False)
    df_Per = pd.read_csv('../../Big_Files/Person_Raw.csv', low_memory=False)
    
    print ('df_Acc.shape = ', df_Acc.shape)
    print ('df_Veh.shape = ', df_Veh.shape)
    print ('df_Per.shape = ', df_Per.shape)
    print ()
    
    return df_Acc, df_Veh, df_Per

#df_Acc, df_Veh, df_Per = Get_Data_from_Temp_Files()

# %% [markdown]
# ## Drop Features

# %% [markdown]
# - We now have three dataframes from the Accident, Vehicle, and Person files.
# - Some features are repeated, so we will drop the ones in Vehicle or Person that appear in Accident, and drop those in Person that appear in Vehicle.
# - There are two repeated features we need to keep for merging the three data:
#     - CASENUM tells us to which accident the vehicle and person correspond
#     - VEH_NO tells us which vehicle the person was in.
# - Some features have no predictive power and/or resemble random numbers, like the VIN (Vehicle Identification Number) and the minute of the accident time.
# - For details on the features, see the *Crash Report Sampling System Analytical User's Manual 2016-2020.*

# %% [markdown]
# ### Drop Repeated Features

# %%
def Drop_Repeated_Features(df_Acc, df_Veh, df_Per):
    print ('Drop_Repeated_Features()')
    Acc_Cols = df_Acc.columns.tolist()
    Veh_Cols = df_Veh.columns.tolist()
    Per_Cols = df_Per.columns.tolist()
    
    Drop_Veh = [x for x in Veh_Cols if x in Acc_Cols]
    Drop_Per = [x for x in Per_Cols if (x in Acc_Cols or x in Veh_Cols)]
        
    print ('Drop_Veh:')
    for item in Drop_Veh:
        print (item)
    print ()

    print ('Drop_Per:')
    for item in sorted(Drop_Per):
        print (item)
    print ()
    
    # We need to keep these for merging the dataframes.
    Drop_Veh.remove('CASENUM')
    Drop_Per.remove('CASENUM')
    Drop_Per.remove('VEH_NO')
    
    df_Veh.drop(columns=Drop_Veh, inplace=True)
    df_Per.drop(columns=Drop_Per, inplace=True)

    print ('df_Acc.shape = ', df_Acc.shape)
    print ('df_Veh.shape = ', df_Veh.shape)
    print ('df_Per.shape = ', df_Per.shape)
    print ()
    
    return df_Acc, df_Veh, df_Per

# %% [markdown]
# ### Drop Irrelevant Features
#
# We will later drop features that are unknowable from the notification, like drug test results, but we still need those features for imputing missing data.  Here we drop features that are either
#
#     - Just noise (like VIN, Vehicle Identification Number),
#     - Only given for a small number of crashes (like trailer weight), or
#     - Only present for some years but not others.

# %%
def Drop_Irrelevant_Features(df_Acc, df_Veh, df_Per):
    
    print ('Drop_Irrelevant_Features')
    
    Drop_Accident = [
        'CF1',
        'CF2',
        'CF3',
        'MINUTE',
        'MINUTE_IM',
        'PSU_VAR',
        'PSUSTRAT',
        'STRATUM',
        'WEATHER1',
        'WEATHER2',
        'WEIGHT',
    ]
    
    df_Acc.drop(columns=Drop_Accident, inplace=True)
    
    print ('Drop Names of Dropped Features in df_Acc')
    for feature in Drop_Accident:
        feature_name = feature + 'NAME'
        if feature_name in df_Acc:
            print (feature_name)
            df_Acc.drop(columns=[feature_name], inplace=True)
    
    # List of features in df_Veh that aren't repeats from df_Acc 
    # that we don't want to use, even for imputation, because
    # they're only for some years or are like random numbers
    Drop_Vehicle = [
        'DR_SF1',
        'DR_SF2',
        'DR_SF3',
        'DR_SF4',
#        'DR_ZIP',
        'GVWR',
        'GVWR_FROM',
        'GVWR_TO',
        'HAZ_ID',
        'ICFINALBODY',
        'MCARR_I1',
        'MCARR_I2',
        'MCARR_ID',
        'TRLR1GVWR',
        'TRLR1VIN',
        'TRLR2GVWR',
        'TRLR2VIN',
        'TRLR3GVWR',
        'TRLR3VIN',
        'UNITTYPE',
        'V_CONFIG',
        'V_Config',
        'VEH_SC1',
        'VEH_SC2',
        'VIN',
        'VPICBODYCLASS',
        'VPICMAKE',
        'VPICMODEL',
    ]
    
    df_Veh.drop(columns=Drop_Vehicle, inplace=True)
    
    print ('Drop Names of Dropped Features in df_Veh')
    for feature in Drop_Vehicle:
        feature_name = feature + 'NAME'
        if feature_name in df_Veh:
            print (feature_name)
            df_Veh.drop(columns=[feature_name], inplace=True)
    
    Drop_Person = [
        'ATST_TYP',
        'DEVTYPE',
        'DEVMOTOR',
        'DRUGRES1',
        'DRUGRES2',
        'DRUGRES3',
        'DRUGTST1',
        'DRUGTST2',
        'DRUGTST3',
        'DSTATUS',
        'HELM_MIS',
        'HELM_USE',
        'P_SF1',
        'P_SF2',
        'P_SF3',
        'STR_VEH',
    ]
    
    df_Per.drop(columns=Drop_Person, inplace=True)
    
    print ('Drop Names of Dropped Features in df_Per')
    for feature in Drop_Person:
        feature_name = feature + 'NAME'
        if feature_name in df_Per:
            print (feature_name)
            df_Per.drop(columns=[feature_name], inplace=True)
    
    
    print ('df_Acc.shape = ', df_Acc.shape)
    print ('df_Veh.shape = ', df_Veh.shape)
    print ('df_Per.shape = ', df_Per.shape)
    print ()
    
    
    return df_Acc, df_Veh, df_Per

# %% [markdown]
# ## Merge Accident, Vehicle, and Person Dataframes

# %%
def Merge(df_Acc, df_Veh, df_Per):
    print ('Merge()')
    print ()

    data = pd.merge(
        df_Acc, df_Veh, 
        on=['CASENUM'],
        how="inner", sort=False
    )
    
    print ('df_Acc.shape')
    print (df_Acc.shape)
    print ('df_Veh.shape')
    print (df_Veh.shape)
    print ('data.shape')
    print (data.shape)
    print ()

    
    data = pd.merge(
        data, df_Per, 
        on=['CASENUM', 'VEH_NO'],
        how="inner", sort=False
    )
    
    print ('df_Acc.shape')
    print (df_Acc.shape)
    print ('df_Veh.shape')
    print (df_Veh.shape)
    print ('df_Per.shape')
    print (df_Per.shape)
    print ('data.shape')
    print (data.shape)
    print ()


    print (data.head())

    return data

# %% [markdown]
# ## Drop Pedestrian Crashes

# %% [markdown]
# A vehicle hitting another vehicle, a tree, or something else large can result in sudden deceleration different enough from hard braking to trigger an automated notification, but an impact with a pedestrian or bicycle is not.  Our work needs to focus on crashes likely to trigger an automated notification, so we will drop pedestrian crashes from our dataset.
#
# One could argue that we should keep pedestrian crashes for information relevant for imputing missing data, but a sample with a pedestrian lacks all vehicle information, so those records would be more harm than help.

# %%
def Remove_Pedestrian_Crashes(data):
    print ('Remove_Pedestrian_Crashes()')
    display(data.PEDS.value_counts())
    n = len(data[data.PEDS>0])
    print ('Removing %d crashes that involve a pedestrian.' % n)
    data = data[data.PEDS==0]
    print ('data.shape: ', data.shape)
    
    # Drop the PEDS column, which now only has value "0".
    # Drop the LOCATION feature, which now only has value "0".
    data.drop(columns=['PEDS','LOCATION'], inplace=True)
    return data

# %% [markdown]
# ## Make Names Dictionary

# %%
def Make_Names_Dictionary(data):
    C = {}
    for feature in data:
        feature_name = feature + 'NAME'
        if feature_name in data:
            A = pd.DataFrame()
            A[feature] = data[feature]
            A[feature_name] = data[feature_name]
            A.dropna(inplace=True)
            A.drop_duplicates(inplace=True)
            A = A.set_index(feature)
#            display(A)
            B = A.to_dict()
#            display(B)
            C.update(B)
#            display(C)
    with open("../../Big_Files/Names_Dictionary.json", "w") as outfile: 
        json.dump(C, outfile)
        
    print ('Reading in Names Dictionary')
    with open('../../Big_Files/Names_Dictionary.json') as json_file:
        D = json.load(json_file)
#    display(D)

    print ()
    print ("print (D['MONTHNAME']['11'])")
    print (D['MONTHNAME']['11'])
    print ()
    
    return D

# %% [markdown]
# ## Make List of Values Signifying Missing or Unknown
# - This list of criteria isn't perfect, but it's good.

# %%
def Missing_Unknown(Dict):
    MU = ['Missing', 'Unknown']
    Unknowns = {}
    for x, obj in Dict.items():
        Name = x[:len(x) - 4]
        print ()
        print(Name)
        if '_IM' not in Name:
            A = []
            for key in obj:
                value = obj[key]
                for mu in MU:
                    if mu in str(value) and 'type' not in str(value): # If the word 'Missing' or 'Unknown' is in the value
                        S = set(str(key))
                        if S <= set(['8','9']) and str(key)[0] == '9': # If the key only has 8's and 9's, and has at least one 9
                            print('0    ', S, " ", key + ':', value)
                            A.append(int(key))
                        else:
                            print('1    ', S, " ", key + ':', value)
            B = {Name:A}
#            print (B)
            Unknowns.update(B)
#            print (Unknowns)
            
    with open("../../Big_Files/Missing_Unknown.json", "w") as outfile: 
        json.dump(Unknowns, outfile)
        
    print ('Reading in Missing/Unknown Dictionary')
    with open('../../Big_Files/Missing_Unknown.json') as json_file:
        C = json.load(json_file)
    display(C)

    return Unknowns

# %% [markdown]
# ## Run:  Get Data and Preprocess
# - CPU times: user 3min 33s, sys: 19.2 s, total: 3min 52s
# - Wall time: 3min 56s

# %%
# %%time
def Preprocess_Data():
    print ('Preprocess_Data()')
    df_Acc, df_Veh, df_Per = Get_Data_from_Original()
    
#    for feature in df_Acc:
#        print ('df_Acc', feature)
#    print ()
#    for feature in df_Veh:
#        print ('df_Veh', feature)
#    print ()
#    for feature in df_Per:
#        print ('df_Per', feature)
#    print ()

#    df_Acc, df_Veh, df_Per = Get_Data_from_Temp_Files()
    df_Acc, df_Veh, df_Per = Drop_Repeated_Features(df_Acc, df_Veh, df_Per)    
    df_Acc, df_Veh, df_Per = Drop_Irrelevant_Features (df_Acc, df_Veh, df_Per)    

    data = Merge (df_Acc, df_Veh, df_Per)
    data = Remove_Pedestrian_Crashes(data)
    
    Dict = Make_Names_Dictionary(data)
    Unknowns = Missing_Unknown(Dict)
    
    # Bin the target variable.  
    # Either the person went to the hospital or didn't; we don't care how the person got to the hospital.
    data['HOSPITAL'] = data['HOSPITAL'].apply(lambda x:1 if x in [1,2,3,4,5] else 0)
    
    data.to_csv('../../Big_Files/CRSS_Merged_Raw_Data.csv', index=False)
    
    data.sample(frac=0.1).to_csv('../../Big_Files/CRSS_Merged_Raw_Data_Sample.csv', index=False)
    print ('Finished Preprocess_Data()')

Preprocess_Data()
# Out:
# Preprocess_Data()
# Get_Data_from_Original()
# Import_Data_Accident()
# 2016 46511
# 2017 54969
# 2018 48443
# 2019 54409
# 2020 54745
# 2021 54200
# 2022 53955
# (367232, 51)
#
# Import_Data_Vehicle()
# 2016 82149
# 2017 97625
# 2018 86105
# 2019 96717
# 2020 94718
# 2021 95785
# 2022 94756
# (647855, 98)
#
# Import_Data_Person()
# 2016 117759
# 2017 138913
# 2018 120230
# 2019 135410
# 2020 131962
# 2021 133734
# 2022 132175
# (910183, 71)
#
# Import_Data_Accident()
# 2016 46511
# 2017 54969
# 2018 48443
# 2019 54409
# 2020 54745
# 2021 54200
# 2022 53955
# (367232, 90)
#
# Import_Data_Vehicle()
# 2016 82149
# 2017 97625
# 2018 86105
# 2019 96717
# 2020 94718
# 2021 95785
# 2022 94756
# (647855, 187)
#
# Import_Data_Person()
# 2016 117759
# 2017 138913
# 2018 120230
# 2019 135410
# 2020 131962
# 2021 133734
# 2022 132175
# (910183, 125)
#
# Drop_Repeated_Features()
# Drop_Veh:
# CASENUM
# PSU
# PJ
# STRATUM
# VE_FORMS
# MONTH
# HOUR
# MINUTE
# HARM_EV
# MAN_COLL
# URBANICITY
# REGION
# PSUSTRAT
# PSU_VAR
# WEIGHT
# STRATUMNAME
# REGIONNAME
# URBANICITYNAME
# MONTHNAME
# HOURNAME
# MINUTENAME
# HARM_EVNAME
# MAN_COLLNAME
#
# Drop_Per:
# BODY_TYP
# BODY_TYPNAME
# CASENUM
# EMER_USE
# EMER_USENAME
# FIRE_EXP
# FIRE_EXPNAME
# GVWR_FROM
# GVWR_FROMNAME
# GVWR_TO
# GVWR_TONAME
# HARM_EV
# HARM_EVNAME
# HOUR
# HOURNAME
# ICFINALBODY
# ICFINALBODYNAME
# IMPACT1
# IMPACT1NAME
# MAKE
# MAKENAME
# MAK_MOD
# MAK_MODNAME
# MAN_COLL
# MAN_COLLNAME
# MINUTE
# MINUTENAME
# MOD_YEAR
# MOD_YEARNAME
# MONTH
# MONTHNAME
# PJ
# PSU
# PSUSTRAT
# PSU_VAR
# REGION
# REGIONNAME
# ROLLOVER
# ROLLOVERNAME
# SCH_BUS
# SCH_BUSNAME
# SPEC_USE
# SPEC_USENAME
# STRATUM
# STRATUMNAME
# TOW_VEH
# TOW_VEHNAME
# URBANICITY
# URBANICITYNAME
# VEH_NO
# VE_FORMS
# VPICBODYCLASS
# VPICBODYCLASSNAME
# VPICMAKE
# VPICMAKENAME
# VPICMODEL
# VPICMODELNAME
# WEIGHT
#
# df_Acc.shape =  (367232, 90)
# df_Veh.shape =  (647855, 165)
# df_Per.shape =  (910183, 69)
#
# Drop_Irrelevant_Features
# Drop Names of Dropped Features in df_Acc
# CF1NAME
# CF2NAME
# CF3NAME
# MINUTENAME
# MINUTE_IMNAME
# STRATUMNAME
# WEATHER1NAME
# WEATHER2NAME
# Drop Names of Dropped Features in df_Veh
# DR_SF1NAME
# DR_SF2NAME
# DR_SF3NAME
# DR_SF4NAME
# GVWRNAME
# GVWR_FROMNAME
# GVWR_TONAME
# HAZ_IDNAME
# ICFINALBODYNAME
# MCARR_I1NAME
# MCARR_I2NAME
# MCARR_IDNAME
# TRLR1GVWRNAME
# TRLR1VINNAME
# TRLR2GVWRNAME
# TRLR2VINNAME
# TRLR3GVWRNAME
# TRLR3VINNAME
# UNITTYPENAME
# V_CONFIGNAME
# V_ConfigNAME
# VEH_SC1NAME
# VEH_SC2NAME
# VINNAME
# VPICBODYCLASSNAME
# VPICMAKENAME
# VPICMODELNAME
# Drop Names of Dropped Features in df_Per
# ATST_TYPNAME
# DEVTYPENAME
# DEVMOTORNAME
# HELM_MISNAME
# HELM_USENAME
# P_SF1NAME
# P_SF2NAME
# P_SF3NAME
# df_Acc.shape =  (367232, 71)
# df_Veh.shape =  (647855, 111)
# df_Per.shape =  (910183, 45)
#
# Merge()
#
# df_Acc.shape
# (367232, 71)
# df_Veh.shape
# (647855, 111)
# data.shape
# (647855, 181)
#
# df_Acc.shape
# (367232, 71)
# df_Veh.shape
# (647855, 111)
# df_Per.shape
# (910183, 45)
# data.shape
# (873784, 224)
#
#         CASENUM  PSU   PJ  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERMVIT  \
# 0  201600014311   44  388         2         2         0     0        2
# 1  201600014311   44  388         2         2         0     0        2
# 2  201600014315   44  388         2         2         0     0        4
# 3  201600014315   44  388         2         2         0     0        4
# 4  201600014315   44  388         2         2         0     0        4
#
#    PERNOTMVIT  NUM_INJ  ...  ALC_RESNAME  DRUGSNAME  HOSPITALNAME  \
# 0           0        0  ...          NaN        NaN           NaN
# 1           0        0  ...          NaN        NaN           NaN
# 2           0        4  ...          NaN        NaN           NaN
# 3           0        4  ...          NaN        NaN           NaN
# 4           0        4  ...          NaN        NaN           NaN
#
#    LOCATIONNAME  SEX_IMNAME  INJSEV_IMNAME  EJECT_IMNAME  PERALCH_IMNAME  \
# 0           NaN         NaN            NaN           NaN             NaN
# 1           NaN         NaN            NaN           NaN             NaN
# 2           NaN         NaN            NaN           NaN             NaN
# 3           NaN         NaN            NaN           NaN             NaN
# 4           NaN         NaN            NaN           NaN             NaN
#
#    SEAT_IMNAME  AGE_IMNAME
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
#
# [5 rows x 224 columns]
# Remove_Pedestrian_Crashes()
# 0     833798
# 1      38631
# 2       1168
# 3        134
# 4         36
# 6          8
# 5          6
# 11         1
# 7          1
# 8          1
# Name: PEDS, dtype: int64
# Removing 39986 crashes that involve a pedestrian.
# data.shape:  (833798, 224)
# Reading in Names Dictionary
#
# print (D['MONTHNAME']['11'])
# November
#
#
# NUM_INJ
# 0     {'9'}   99: All Persons in Crash are Unknown If Injured
#
# MONTH
#
# YEAR
#
# DAY_WEEK
#
# HOUR
# 0     {'9'}   99: Unknown Hours
#
# HARM_EV
# 1     {'1', '9'}   91: Unknown Object Not Fixed
# 1     {'3', '9'}   93: Unknown Fixed Object
# 0     {'9'}   99: Reported as Unknown
#
# ALCOHOL
# 0     {'9'}   9: Reported as Unknown
#
# MAX_SEV
# 0     {'9'}   9: Unknown/Not Reported
# 1     {'5'}   5: Injured, Severity Unknown
#
# MAN_COLL
# 0     {'9'}   99: Reported as Unknown
#
# RELJCT1
# 0     {'9'}   9: Reported as Unknown
#
# RELJCT2
# 0     {'9'}   99: Reported as Unknown
#
# TYP_INT
# 0     {'9'}   99: Reported as Unknown
#
# WRK_ZONE
# 1     {'4'}   4: Work Zone, Type Unknown
#
# REL_ROAD
# 1     {'6'}   6: Off Roadway-Location Unknown
# 0     {'9'}   99: Reported as Unknown
#
# LGT_COND
# 0     {'9'}   9: Reported as Unknown
# 1     {'6'}   6: Dark - Unknown Lighting
#
# WEATHER
# 0     {'9'}   99: Reported as Unknown
#
# SCH_BUS
#
# INT_HWY
# 0     {'9'}   9: Unknown
#
# WKDY_IM
#
# HOUR_IM
#
# EVENT1_IM
#
# MANCOL_IM
#
# RELJCT1_IM
#
# RELJCT2_IM
#
# LGTCON_IM
#
# WEATHR_IM
#
# MAXSEV_IM
#
# NO_INJ_IM
#
# ALCHL_IM
#
# URBANICITY
#
# REGION
#
# NUMOCCS
# 0     {'9'}   99: Unknown
#
# HIT_RUN
# 0     {'9'}   9: Reported as Unknown
#
# MAKE
# 0     {'9'}   99: Unknown Make
#
# BODY_TYP
# 1     {'5', '9'}   59: Unknown Bus Type
# 1     {'7', '1'}   71: Unknown if single-unit or combination unit Medium Truck (GVWR range 10,001 lbs. to 26,000 lbs.)
# 1     {'7', '2'}   72: Unknown if single-unit or combination unit Heavy Truck (GVWR greater than 26,000 lbs.)
# 1     {'7', '8'}   87: Unknown Three Wheel Motorcycle Type
#
# MOD_YEAR
# 0     {'9'}   9999: Unknown
#
# MAK_MOD
# 1     {'7', '4', '8'}   87884: Peterbilt Medium/Heavy - Unknown engine location
# 1     {'4', '9', '2'}   2499: Jeep / Kaiser-Jeep / Willys- Jeep Unknown (light truck)
# 0     {'9'}   99999: Unknown Make Unknown (as to automobile, motored cycle, light truck or truck)
# 1     {'3', '5', '9'}   35399: Nissan/Datsun Unknown (automobile)
# 1     {'4', '9'}   99499: Unknown Make Unknown (light truck)
# 1     {'4', '8'}   84884: International Harvester/Navistar Medium/Heavy - Unknown engine location
# 1     {'4', '8', '6'}   86884: Mack Medium/Heavy - Unknown engine location
# 1     {'4', '8', '9'}   99884: Unknown Make Medium/Heavy - Unknown engine location
# 1     {'4', '5', '8'}   85884: Kenworth Medium/Heavy - Unknown engine location
# 1     {'3', '4', '5', '9'}   54399: Acura Unknown (automobile)
# 1     {'7', '8', '0', '9'}   98709: Other Make Unknown cc
# 1     {'3', '5', '9'}   53999: Suzuki Unknown (SUZUKI)
# 1     {'4', '8', '2'}   82884: Freightliner Medium/Heavy - Unknown engine location
# 1     {'3', '9'}   99399: Unknown Make Unknown (automobile)
# 1     {'7', '6', '9', '0'}   76709: Yamaha Unknown cc
# 1     {'1', '3', '8', '9'}   18399: Buick / Opel Unknown (automobile)
# 1     {'3', '4', '9'}   49399: Toyota Unknown (automobile)
# 1     {'7', '0', '9'}   99709: Unknown Make Unknown cc
# 1     {'7', '3', '0', '9'}   73709: Kawasaki Unknown cc
# 1     {'1', '4', '9', '2'}   12499: Ford Unknown (light truck)
# 1     {'0', '9', '2'}   20999: Chevrolet Unknown (CHEVROLET)
# 1     {'5', '9'}   55999: Hyundai Unknown (HYUNDAI)
# 1     {'3', '5', '9'}   35999: Nissan/Datsun Unknown (NISSAN/DATSUN)
# 1     {'3', '5', '8', '9'}   58399: Infiniti Unknown (automobile)
# 1     {'3', '0', '9', '7'}   37709: Honda Unknown cc
# 1     {'1', '8', '9', '2'}   12989: Ford Unknown (bus)
# 1     {'3', '0', '9', '2'}   20399: Chevrolet Unknown (automobile)
# 1     {'4', '5', '9'}   59499: Lexus Unknown (light truck)
# 0     {'8', '9'}   99898: Unknown Make Other (medium/heavy truck)
# 1     {'1', '3', '9', '2'}   12399: Ford Unknown (automobile)
# 1     {'4', '0', '9', '2'}   20499: Chevrolet Unknown (light truck)
# 1     {'3', '9', '2'}   22399: Pontiac Unknown (automobile)
# 1     {'7', '3', '9'}   7399: Dodge Unknown (automobile)
# 1     {'4', '9'}   49999: Toyota Unknown (TOYOTA)
# 1     {'3', '5', '9'}   55399: Hyundai Unknown (automobile)
# 1     {'4', '8', '9'}   98884: Other Make Medium/Heavy - Unknown engine location
# 1     {'9', '2'}   22999: Pontiac Unknown (PONTIAC)
# 1     {'3', '4', '8', '9'}   38499: Isuzu Unknown (light truck)
# 1     {'1', '8', '9'}   99881: Unknown Make Medium/Heavy - CBE
# 0     {'8', '9'}   99989: Unknown Make Unknown (bus)
# 1     {'7', '0', '9', '2'}   72709: Harley-Davidson Unknown cc
# 1     {'4', '8', '0', '2'}   20884: Chevrolet Medium/Heavy -Unknown engine location
# 1     {'3', '9', '7'}   37399: Honda Unknown (automobile)
# 1     {'3', '5', '9'}   59399: Lexus Unknown (automobile)
# 1     {'3', '4', '8', '9'}   48399: Subaru Unknown (automobile)
# 1     {'4', '9'}   49499: Toyota Unknown (light truck)
# 1     {'3', '0', '9'}   30399: Volkswagen Unknown (automobile)
# 1     {'3', '6', '9'}   6399: Chrysler Unknown (automobile)
# 1     {'1', '4', '8', '9'}   18499: Buick / Opel Unknown (light truck)
# 1     {'1', '3', '9'}   19399: Cadillac Unknown (automobile)
# 0     {'8', '9'}   99998: Unknown Make Other (vehicle)
# 1     {'9', '0', '3', '7', '5'}   53709: Suzuki Unknown cc
# 1     {'8', '0', '9'}   99890: Unknown Make Medium/Heavy - COE entry position unknown
# 1     {'1', '4', '5', '9'}   51499: Volvo Unknown (light truck)
# 1     {'1', '4', '3', '9'}   14399: Mercury Unknown (automobile)
# 1     {'3', '4', '9', '2'}   42399: Mercedes-Benz Unknown (automobile)
# 1     {'3', '0', '9'}   30999: Volkswagen Unknown (VOLKSWAGEN)
# 1     {'3', '4', '9'}   34499: BMW Unknown (light truck)
# 1     {'3', '4', '6', '9'}   63499: KIA Unknown (light truck)
# 1     {'7', '4', '9'}   7499: Dodge Unknown (light truck)
# 1     {'4', '5', '9'}   54999: Acura Unknown (ACURA)
# 1     {'7', '3', '8', '9'}   98739: Other Make Unknown cc (ATV)
# 1     {'1', '8', '9'}   99981: Unknown Make Bus**: Conventional (Engine out front)
# 1     {'7', '3', '9'}   99739: Unknown Make Unknown cc (ATV)
# 1     {'1', '5', '3', '9'}   51399: Volvo Unknown (automobile)
# 1     {'3', '4', '9', '2'}   23499: GMC Unknown (light truck)
# 1     {'3', '9', '7'}   37999: Honda Unknown (HONDA)
# 1     {'3', '4', '9', '7'}   37499: Honda Unknown (light truck)
# 1     {'3', '4', '5', '9'}   35499: Nissan/Datsun Unknown (light truck)
# 1     {'3', '5', '9', '2'}   52399: Mitsubishi Unknown (automobile)
# 1     {'7', '9'}   7999: Dodge Unknown (DODGE)
# 1     {'3', '4', '9', '2'}   24399: Saturn Unknown (automobile)
# 1     {'3', '6', '9'}   63399: KIA Unknown (automobile)
# 1     {'3', '4', '9'}   34399: BMW Unknown (automobile)
# 1     {'1', '4', '3', '9'}   41399: Mazda Unknown (automobile)
# 1     {'3', '6', '9'}   63999: KIA Unknown (KIA)
# 1     {'7', '4', '9'}   47999: Saab Unknown(SAAB)
# 1     {'1', '8', '9'}   18999: Buick / Opel Unknown BUICK
# 1     {'3', '9', '2'}   23999: GMC Unknown (GMC)
# 1     {'4', '8', '9'}   48999: Subaru Unknown (SUBARU)
# 1     {'4', '8', '9'}   48499: Subaru Unknown (light truck)
# 1     {'3', '9', '2'}   32399: Audi Unknown (automobile)
# 1     {'3', '5', '6', '9'}   65399: Smart Unknown (automobile)
# 1     {'9', '2'}   2999: Jeep / Kaiser-Jeep / Willys- Jeep Unknown (JEEP)
# 1     {'5', '8', '9'}   58999: Infiniti Unknown (INFINITI)
# 1     {'1', '4', '9'}   41499: Mazda Unknown (light truck)
# 1     {'1', '5', '9'}   51999: Volvo Unknown (VOLVO)
# 1     {'1', '4', '9'}   19499: Cadillac Unknown (light truck)
# 1     {'1', '9'}   19999: Cadillac Unknown CADILLAC
# 1     {'3', '4', '5', '9'}   45399: Porsche Unknown (automobile)
# 1     {'4', '9', '2'}   42499: Mercedes-Benz Unknown (light truck)
# 1     {'3', '4', '0', '9'}   30499: Volkswagen Unknown (light truck)
# 1     {'1', '3', '9'}   13399: Lincoln Unknown (automobile)
# 1     {'3', '4', '9'}   34999: BMW Unknown (BMW)
# 1     {'7', '4', '3', '9'}   47399: Saab Unknown (automobile)
# 1     {'1', '3', '9', '2'}   21399: Oldsmobile Unknown (automobile)
# 1     {'5', '9'}   59999: Lexus Unknown (LEXUS)
# 1     {'4', '9', '2'}   22499: Pontiac Unknown (light truck)
# 1     {'6', '9'}   6999: Chrysler Unknown (CHRYSLER)
# 1     {'4', '9', '2'}   24999: Saturn Unknown (SATURN)
# 1     {'1', '9', '2'}   12999: Ford Unknown (FORD)
# 1     {'1', '4', '8', '2'}   12884: Ford Medium/Heavy - Unknown engine location
# 1     {'4', '9', '2'}   42999: Mercedes-Benz Unknown (MERCEDES-BENZ)
# 1     {'8', '0', '9', '2'}   20989: Chevrolet Unknown (bus)
# 1     {'4', '8', '9'}   94989: Thomas Built Unknown (bus)
# 1     {'5', '8', '0', '9'}   99850: Unknown Make Motor Home
# 1     {'7', '1', '0', '9'}   71709: Ducati Unknown cc
# 1     {'7', '3', '6', '9'}   67399: Scion Unknown (automobile)
# 1     {'4', '6', '9', '2'}   62499: Land Rover Unknown (light truck)
# 1     {'7', '0', '9'}   77709: Victory Unknown cc
# 1     {'7', '1', '0', '9'}   99701: Unknown Make 0-50cc
# 1     {'7', '5', '0', '9'}   50709: Triumph Unknown cc
# 1     {'4', '8', '9'}   84989: International Harvester/Navistar Unknown (bus)
# 1     {'3', '4', '9'}   3499: AM General Unknown (light truck)
# 0     {'8', '9'}   99988: Unknown Make Other (bus)
# 1     {'3', '9', '2'}   29399: Other Domestic Manufacturers Unknown (automobile)
# 1     {'1', '4', '9'}   14999: Mercury Unknown (MERCURY)
# 1     {'1', '4', '9'}   41999: Mazda Unknown (MAZDA)
# 1     {'4', '6', '9'}   6499: Chrysler Unknown (light truck)
# 1     {'1', '4', '5', '8'}   51884: Volvo Medium/Heavy - Unknown engine location
# 1     {'5', '9', '2'}   52999: Mitsubishi Unknown (MITSUBISHI)
# 1     {'8', '0', '9'}   90989: Bluebird Unknown (Bus)
# 1     {'1', '9', '2'}   21999: Oldsmobile Unknown (OLDSMOBILE)
# 1     {'9', '0', '3', '4', '7'}   34709: BMW Unknown cc
# 1     {'3', '8', '9'}   38999: Isuzu Unknown (ISUZU)
# 1     {'3', '4', '9', '2'}   32499: Audi Unknown (light truck)
# 1     {'3', '9', '2'}   32999: Audi Unknown (AUDI)
# 1     {'3', '9', '2'}   23399: GMC Unknown (automobile)
# 1     {'1', '3', '9'}   13999: Lincoln Unknown (LINCOLN)
# 1     {'3', '6', '9'}   36399: Fiat Unknown (automobile)
# 1     {'4', '5', '9'}   55499: Hyundai Unknown (light truck)
# 1     {'1', '4', '9'}   14499: Mercury Unknown (light truck)
# 1     {'5', '8', '9'}   85999: Kenworth Unknown (KENWORTH)
# 1     {'4', '5', '9', '2'}   52499: Mitsubishi Unknown (light truck)
# 1     {'3', '8', '9'}   93989: MCI Unknown (bus)
# 1     {'7', '5', '0', '9'}   50799: Triumph Unknown (motored cycle)
# 1     {'7', '3', '0', '9'}   99703: Unknown Make 125-349cc
# 0     {'8', '9'}   98999: Other Make Unknown (OTHER MAKE)
# 1     {'4', '8', '9'}   84999: International Harvester/Navistar Unknown (INTL. HARVESTER/ NAVISTAR)
# 1     {'4', '5', '9'}   45499: Porsche Unknown (light truck)
# 1     {'4', '5', '9'}   54499: Acura Unknown (light truck)
# 1     {'4', '9', '2'}   24499: Saturn Unknown (Light truck)
# 1     {'7', '8', '0', '9'}   99870: Unknown Make Medium Heavy Van-Based Vehicle
# 1     {'3', '4', '8'}   38884: Isuzu Medium/Heavy - Unknown engine location
# 1     {'3', '9'}   39399: Jaguar Unknown (automobile)
# 1     {'3', '9'}   9399: Plymouth Unknown (automobile)
# 1     {'3', '4', '8', '2'}   23884: GMC Medium/Heavy - Unknown engine location
# 1     {'3', '4', '5', '9'}   53499: Suzuki Unknown (light truck)
# 1     {'7', '0', '9'}   99707: Unknown Make Electric Motorcycle
# 1     {'7', '3', '9'}   73739: Kawasaki Unknown cc (ATV)
# 1     {'1', '4', '3', '9'}   13499: Lincoln Unknown (light truck)
# 1     {'3', '9'}   39999: Jaguar Unknown (JAGUAR)
# 1     {'4', '5', '8', '9'}   58499: Infiniti Unknown (Light Truck)
# 1     {'3', '8', '9'}   38399: Isuzu Unknown (automobile)
# 1     {'4', '9'}   9499: Plymouth Unknown (light truck)
# 1     {'3', '5', '9'}   53399: Suzuki Unknown (automobile)
# 1     {'8', '9', '2'}   82999: Freightliner Unknown (FREIGHTLINER)
# 1     {'8', '2', '9'}   92989: Gillig Unknown (bus)
# 1     {'3', '9', '7'}   37739: Honda Unknown cc (ATV)
# 1     {'3', '1', '9'}   31399: Alfa Romeo Unknown (automobile)
# 1     {'8', '9', '2'}   82989: Freightliner Unknown (bus)
# 1     {'4', '5', '9'}   45999: Porsche Unknown(PORSCHE)
# 1     {'3', '6', '9'}   69399: Other Import Unknown (automobile)
# 1     {'3', '1', '9'}   31999: Alfa Romeo Unknown (ALFA ROMEO)
# 1     {'1', '4', '9', '2'}   21499: Oldsmobile Unknown (light truck)
# 1     {'5', '9', '2'}   25999: Grumman Unknown (GRUMMAN/ GRUMMAN-OLSON)
# 1     {'7', '3', '6', '9'}   76739: Yamaha Unknown cc (ATV)
# 1     {'4', '8', '9'}   89884: White/Autocar White/GMC Medium/Heavy - Unknown engine location
# 0     {'9'}   9999: Plymouth Unknown (PLYMOUTH)
# 1     {'4', '8', '9', '2'}   82499: Freightliner Unknown (light truck)
# 1     {'3', '9'}   3999: AM General Unknown (AM GENERAL)
# 1     {'7', '8', '9'}   87999: Peterbilt Unknown (PETERBILT)
# 1     {'3', '5', '9', '7'}   53739: Suzuki Unknown cc (ATV)
# 1     {'8', '6', '9'}   86999: Mack Unknown (MACK)
# 1     {'1', '5', '8', '9'}   51989: Volvo Unknown (bus)
# 1     {'3', '5', '0', '9'}   50399: Triumph Unknown (automobile)
# 1     {'3', '4', '6', '9'}   36499: Fiat Unknown (light truck)
# 1     {'7', '4', '8'}   7884: Dodge Medium/Heavy -Unknown engine location
# 1     {'3', '8', '9', '2'}   23989: GMC Unknown (bus)
# 1     {'7', '4', '0', '9'}   74709: Moto-Guzzi Unknown cc
# 1     {'4', '5', '9', '2'}   25499: Grumman Unknown (light truck)
# 1     {'7', '5', '0', '9'}   75709: Norton Unknown cc
# 1     {'3', '4', '9'}   39499: Jaguar Unknown (light truck)
# 1     {'3', '6', '9'}   36999: Fiat Unknown (FIAT)
#
# TOW_VEH
# 0     {'9'}   9: Unknown
# 1     {'4'}   4: Yes, Number of Trailers Unknown
#
# J_KNIFE
#
# CARGO_BT
# 0     {'8', '9'}   98: Unknown Cargo Body Type
# 0     {'9'}   99: Unknown
#
# HAZ_INV
#
# HAZ_PLAC
#
# HAZ_CNO
#
# HAZ_REL
#
# BUS_USE
# 0     {'9'}   99: Reported as Unknown
# 1     {'7', '9'}   97: Bus, Unknown Use
#
# SPEC_USE
# 0     {'9'}   99: Reported as Unknown
#
# EMER_USE
# 0     {'9'}   9: Reported as Unknown
# 1     {'6'}   6: Emergency Operation, Emergency Warning Equipment in Use Unknown
#
# TRAV_SP
# 0     {'9'}   999: Reported as Unknown
#
# ROLLOVER
# 0     {'9'}   9: Rollover, Unknown Type
#
# ROLINLOC
# 0     {'9'}   9: Unknown
#
# IMPACT1
# 0     {'9'}   99: Reported as Unknown
# 1     {'0', '2'}   20: Object Set in Motion, Unknown if Cargo/Vehicle Parts or Other
#
# DEFORMED
# 0     {'9'}   9: Reported as Unknown
# 1     {'7'}   7: Damage Reported, Extent Unknown
#
# TOWED
# 1     {'7'}   7: Towed, Unknown Reason
# 0     {'9'}   9: Reported as Unknown
#
# M_HARM
# 1     {'1', '9'}   91: Unknown Object Not Fixed
# 1     {'3', '9'}   93: Unknown Fixed Object
# 0     {'9'}   99: Reported as Unknown
#
# VEH_ALCH
# 0     {'9'}   9: Reported as Unknown
#
# MAX_VSEV
# 0     {'9'}   9: Unknown/Not Reported
# 1     {'5'}   5: Injured, Severity Unknown
#
# NUM_INJV
#
# FIRE_EXP
#
# DR_PRES
# 0     {'9'}   9: Unknown
#
# DR_ZIP
# 0     {'9'}   99999: Reported as Unknown
# 1     {'7', '9'}   99997: No Driver Present/Unknown if Driver Present
#
# SPEEDREL
# 0     {'9'}   9: Reported as Unknown
# 1     {'5'}   5: Yes, Specifics Unknown
# 1     {'8'}   8: No Driver Present/Unknown if Driver Present
#
# VTRAFWAY
# 0     {'9'}   9: Reported as Unknown
# 1     {'7'}   7: Two-Way Divided, Unknown if Unprotected Median or Positive Median Barrier
#
# VNUM_LAN
# 0     {'9'}   9: Reported as Unknown
#
# VSPD_LIM
# 0     {'9'}   99: Reported as Unknown
#
# VALIGN
# 1     {'4'}   4: Curve - Unknown Direction
# 0     {'9'}   9: Reported as Unknown
#
# VPROFILE
# 1     {'2'}   2: Grade, Unknown Slope
# 0     {'9'}   9: Reported as Unknown
#
# VSURCOND
# 0     {'9'}   99: Reported as Unknown
#
# VTRAFCON
# 0     {'9'}   99: Reported as Unknown
# 0     {'9'}   9: Unknown Highway Traffic Signal
# 1     {'9', '2'}   29: Unknown Regulatory Sign
#
# VTCONT_F
# 0     {'9'}   9: Reported as Unknown
# 1     {'4'}   4: Device Not Functioning or Device Functioning Improperly, Specifics Unknown
#
# P_CRASH1
# 0     {'9'}   99: Unknown
# 1     {'0'}   0: No Driver Present / Unknown if Driver Present
#
# P_CRASH2
# 1     {'5', '9'}   59: Unknown Travel Direction/Speed of Other Motor Vehicle in Lane
# 0     {'9'}   99: Unknown
# 1     {'1', '9'}   19: Unknown travel direction
# 0     {'9'}   9: Unknown cause of control loss
#
# P_CRASH3
# 0     {'9'}   99: Unknown/Not Reported
# 1     {'1', '5'}   15: Braking and Unknown Steering Direction
# 1     {'0'}   0: No Driver Present / Unknown if Driver Present
#
# PCRASH4
# 1     {'5'}   5: Skidding Laterally, Rotation Direction Unknown
# 1     {'0'}   0: No Driver Present / Unknown if Driver Present
#
# PCRASH5
# 0     {'9'}   9: Unknown
# 1     {'0'}   0: No Driver Present / Unknown if Driver Present
#
# ACC_TYPE
# 1     {'1', '6'}   16: C16-Single Driver-Forward Impact-Specifics Unknown
# 1     {'7', '5'}   75: J75-Trafficway Vehicle Turning-Turn Across Path-Specifics Unknown
# 0     {'9'}   99: M99-Unknown
# 1     {'3'}   33: D33-Same Trafficway, Same Direction-Rear End-Specifics Unknown
# 1     {'4', '9'}   49: F49-Same Trafficway, Same Direction-Angle, Sideswipe-Specifics Unknown
# 1     {'1', '9'}   91: L91-Intersecting Paths-Straight Paths-Specifics Unknown
# 1     {'5', '8'}   85: K85-Trafficway Vehicle Turning-Turn Into Path-Specifics Unknown
# 1     {'5'}   5: A5-Single Driver-Right Roadside Departure-Specifics Unknown
# 1     {'7', '6'}   67: I67-Same Trafficway, Opposite Direction-Angle, Sideswipe-Specifics Unknown
# 1     {'3', '5'}   53: G53-Same Trafficway, Opposite Direction-Head-On-Specifics Unknown
# 1     {'1', '0'}   10: B10-Single Driver-Left Roadside Departure-Specifics Unknown
# 1     {'3', '4'}   43: E43-Same Trafficway, Same Direction-Forward Impact-Specifics Unknown
# 1     {'3', '6'}   63: H63-Same Trafficway, Opposite Direction-Forward Impact-Specifics Unknown
#
# HITRUN_IM
#
# BDYTYP_IM
#
# MDLYR_IM
#
# IMPACT1_IM
#
# VEVENT_IM
#
# PCRASH1_IM
#
# MXVSEV_IM
#
# NUMINJ_IM
#
# V_ALCH_IM
#
# UNDEROVERRIDE
# 1     {'0', '.', '9'}   9.0: Reported as Unknown
#
# AGE
# 0     {'9'}   999: Reported as Unknown
#
# SEX
# 0     {'9'}   9: Reported as Unknown
#
# PER_TYP
# 0     {'9'}   9: Unknown Occupant Type in a Motor Vehicle In- Transport
#
# INJ_SEV
# 0     {'9'}   9: Unknown/Not Reported
# 1     {'5'}   5: Injured, Severity Unknown
#
# SEAT_POS
# 1     {'1', '9'}   19: Front Seat, Unknown
# 1     {'9', '2'}   29: Second Seat, Unknown
# 0     {'9'}   99: Reported as Unknown
# 1     {'3', '9'}   39: Third Seat, Unknown
#
# REST_USE
# 0     {'9'}   99: Reported as Unknown
# 1     {'8'}   8: Restraint Used - Type Unknown
# 1     {'4'}   4: Child Restraint Type Unknown
#
# REST_MIS
#
# AIR_BAG
# 0     {'9'}   99: Reported as Deployment Unknown
# 0     {'9'}   9: Deployment- Unknown Location
#
# EJECTION
# 0     {'9'}   9: Reported as Unknown if Ejected
# 1     {'3'}   3: Ejected - Unknown Degree
#
# DRINKING
# 0     {'9'}   9: Reported as Unknown
#
# ALC_STATUS
# 0     {'9'}   9: Reported as Unknown if Tested
#
# ALC_RES
# 1     {'7', '9'}   997: AC Test Performed, Results Unknown
# 0     {'9'}   999: Reported as Unknown if Tested
#
# DRUGS
# 0     {'9'}   9: Reported as Unknown
#
# HOSPITAL
# 1     {'3'}   3: EMS Unknown Mode
# 1     {'4'}   4: Transported  Unknown Source
# 0     {'9'}   9: Reported as Unknown
#
# SEX_IM
#
# INJSEV_IM
#
# EJECT_IM
#
# PERALCH_IM
#
# SEAT_IM
#
# AGE_IM
# Reading in Missing/Unknown Dictionary
# {'NUM_INJ': [99],
#  'MONTH': [],
#  'YEAR': [],
#  'DAY_WEEK': [],
#  'HOUR': [99],
#  'HARM_EV': [99],
#  'ALCOHOL': [9],
#  'MAX_SEV': [9],
#  'MAN_COLL': [99],
#  'RELJCT1': [9],
#  'RELJCT2': [99],
#  'TYP_INT': [99],
#  'WRK_ZONE': [],
#  'REL_ROAD': [99],
#  'LGT_COND': [9],
#  'WEATHER': [99],
#  'SCH_BUS': [],
#  'INT_HWY': [9],
#  'URBANICITY': [],
#  'REGION': [],
#  'NUMOCCS': [99],
#  'HIT_RUN': [9],
#  'MAKE': [99],
#  'BODY_TYP': [],
#  'MOD_YEAR': [9999],
#  'MAK_MOD': [99999, 99898, 99989, 99998, 99988, 98999, 9999],
#  'TOW_VEH': [9],
#  'J_KNIFE': [],
#  'CARGO_BT': [98, 99],
#  'HAZ_INV': [],
#  'HAZ_PLAC': [],
#  'HAZ_CNO': [],
#  'HAZ_REL': [],
#  'BUS_USE': [99],
#  'SPEC_USE': [99],
#  'EMER_USE': [9],
#  'TRAV_SP': [999],
#  'ROLLOVER': [9],
#  'ROLINLOC': [9],
#  'IMPACT1': [99],
#  'DEFORMED': [9],
#  'TOWED': [9],
#  'M_HARM': [99],
#  'VEH_ALCH': [9],
#  'MAX_VSEV': [9],
#  'NUM_INJV': [],
#  'FIRE_EXP': [],
#  'DR_PRES': [9],
#  'DR_ZIP': [99999],
#  'SPEEDREL': [9],
#  'VTRAFWAY': [9],
#  'VNUM_LAN': [9],
#  'VSPD_LIM': [99],
#  'VALIGN': [9],
#  'VPROFILE': [9],
#  'VSURCOND': [99],
#  'VTRAFCON': [99, 9],
#  'VTCONT_F': [9],
#  'P_CRASH1': [99],
#  'P_CRASH2': [99, 9],
#  'P_CRASH3': [99],
#  'PCRASH4': [],
#  'PCRASH5': [9],
#  'ACC_TYPE': [99],
#  'UNDEROVERRIDE': [],
#  'AGE': [999],
#  'SEX': [9],
#  'PER_TYP': [9],
#  'INJ_SEV': [9],
#  'SEAT_POS': [99],
#  'REST_USE': [99],
#  'REST_MIS': [],
#  'AIR_BAG': [99, 9],
#  'EJECTION': [9],
#  'DRINKING': [9],
#  'ALC_STATUS': [9],
#  'ALC_RES': [999],
#  'DRUGS': [9],
#  'HOSPITAL': [9]}
# Finished Preprocess_Data()
# CPU times: user 3min 14s, sys: 16.3 s, total: 3min 30s
# Wall time: 3min 35s
